# %%
import twitter
import os
import tweepy as tw
import pandas as pd
# https://www.r-bloggers.com/2016/02/setting-up-the-twitter-r-package-for-text-analytics/
consumer_key= '8YZybjQ7RuoIosBEU5MWub17g'
consumer_secret= 'UsqSyisuEB5lb51AliGID0E1g8FtpJxhQc4yn9UdKS9MSecec7'
access_token= '629232543-oEZlZ65G23GGI0LHO24izbgn6eUj6OGlb1UPMlgT'
access_token_secret= 'R9I4xbgczStXWHYKgIcWnfuMxXoWgKaNHBydab6RFrT0y'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)
# https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/twitter-data-in-python/#:~:text=Once%20you%20have%20your%20Twitter,importing%20the%20necessary%20Python%20libraries.&text=To%20access%20the%20Twitter%20API,Keys%20and%20Access%20Tokens%20tab.

# %%
# Define the search term and the date_since date as variables
search_words = "#wildfires"
date_since = "2018-11-16"

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)
print (tweets)

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)

# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @CCharitiesUSA: @CCharitiesUSA is the domestic disaster relief agency of the US Catholic Church and provides immediate relief and long-t…
# @CCharitiesUSA is the domestic disaster relief agency of the US Catholic Church and provides immediate relief and l… https://t.co/WVaSFGElUu
# RT @DIEBO37: WildFire Nightmare Continues. #𝔊𝕯𝔏𝔈 #WildFires #Environment
# https://t.co/Zmio6lxk1v #California https://t.co/kfdS8JTb4s
# RT @TSIIncorporated: This spring, using TSI SidePak AM520 personal air monitors, researchers at Montana Technological University measured i…
# RT @CAL_FIRE: When we are not fighting fires, we are putting forth every effort to prevent them. This includes having our fuel crews remove…

# %%
new_search = search_words + " -filter:retweets"
new_search
# Out:
# '#wildfires -filter:retweets'

# %%
tweets = tw.Cursor(api.search,
                       q=new_search,
                       lang="en",
                       since=date_since).items(5)

[tweet.text for tweet in tweets]
# Out:
# ['@CCharitiesUSA is the domestic disaster relief agency of the US Catholic Church and provides immediate relief and l… https://t.co/WVaSFGElUu',
#  "Free slideshow. Why Prepare Now? Because It's Too Late After A Disaster Strikes  https://t.co/UkaGEQMBlm   via… https://t.co/3lQE8r9LMO",
#  'Can "raking the floors" of the forests really help with fire prevention? Turns out fire prevention uses more tools… https://t.co/sUbHrRUlOl',
#  'My latest recording project - vocals &amp; accordion. A neat song by Joe Peters &amp; words by Mike Rothman. Mike Kelsey is… https://t.co/K9y2dnLsnG',
#  'Flash #floods, #wildfires &amp; #hurricanes have made an already difficult year that much harder to navigate. That’s wh… https://t.co/ZeTymaXVXW']

# %%
tweets = tw.Cursor(api.search,
                           q=new_search,
                           lang="en",
                           since=date_since).items(5)

users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs
# Out:
# [['CCharitiesUSA', 'Alexandria, VA'],
#  ['GB_Survival', ''],
#  ['davesgardenteam', "Dave's Garden"],
#  ['vickiemaris', 'Global'],
#  ['floodtweeter', 'St Petersburg  FL']]

# %%
tweet_text = pd.DataFrame(data=users_locs,
                    columns=['user', "location"])
tweet_text
# Out:
#               user           location
# 0    CCharitiesUSA     Alexandria, VA
# 1      GB_Survival
# 2  davesgardenteam      Dave's Garden
# 3      vickiemaris             Global
# 4     floodtweeter  St Petersburg  FL

# %%
new_search = "climate+change -filter:retweets"

tweets = tw.Cursor(api.search,
                   q=new_search,
                   lang="en",
                   since='2018-04-23').items(1000)

all_tweets = [tweet.text for tweet in tweets]
all_tweets[:5]
# Out:
# ['The#KPMGIMPACT survey report with @Esgloballaw seeks to uncover the barriers and opportunities in the global corpor… https://t.co/45SOgDRbYv',
#  'The speakers in Squarzoni’s novel are mostly white, french, and experts in climate change. Not much diversity at all.',
#  '@illdiscourse Unseasonably Warm December Portends Climate Change Disaster',
#  '@bomparelli @JaggerMickOZ Climate change alarmists fueling the fear of the left, like Stephen Mann &amp; Gerald Kutney.… https://t.co/NpeVdZDpag',
#  '@YellowTurtle17 @Defend_Trump @realDonaldTrump @Mike_Pence @GretaThunberg If Climate Change was only about reducing… https://t.co/7V0AyxMaph']

# %%
fn_twitter = searchTwitter("#Houston",n=1000,lang="en")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9b836b5dd268> in <module>
# ----> 1 fn_twitter = searchTwitter("#Houston",n=1000,lang="en")
#
# NameError: name 'searchTwitter' is not defined

# %%
from twitter import *
consumer_key= '8YZybjQ7RuoIosBEU5MWub17g'
consumer_secret= 'UsqSyisuEB5lb51AliGID0E1g8FtpJxhQc4yn9UdKS9MSecec7'
token = '629232543-oEZlZ65G23GGI0LHO24izbgn6eUj6OGlb1UPMlgT'
token_secret= 'R9I4xbgczStXWHYKgIcWnfuMxXoWgKaNHBydab6RFrT0y'


t = Twitter(
    auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# %%
data = t.search.tweets(q="#pycon")
type (data)
data
# Out:
# {'statuses': [{'created_at': 'Thu Nov 12 17:27:51 +0000 2020',
#    'id': 1326939780362330117,
#    'id_str': '1326939780362330117',
#    'text': 'RT @AriyaHidayat: This year, Pycon ID 2020, @id_python conference is going virtual! Superstoked to join @mariatta and @nnja to be part of t…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AriyaHidayat',
#       'name': 'Ariya Hidayat',
#       'id': 15608761,
#       'id_str': '15608761',
#       'indices': [3, 16]},
#      {'screen_name': 'id_python',
#       'name': 'Python Indonesia',
#       'id': 340272277,
#       'id_str': '340272277',
#       'indices': [44, 54]},
#      {'screen_name': 'mariatta',
#       'name': 'Mariatta 🤦',
#       'id': 17009144,
#       'id_str': '17009144',
#       'indices': [104, 113]},
#      {'screen_name': 'nnja',
#       'name': 'Nina Zakharenko 💜🐍',
#       'id': 17513031,
#       'id_str': '17513031',
# ...

# %%
# reading the JSON data using json.load()
file = 'data.json'
with open(file) as train_file:
    dict_train = json.load(train_file)

# converting json dataset from dictionary to dataframe
train = pd.DataFrame.from_dict(dict_train, orient='index')
train.reset_index(level=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-31266daf1749> in <module>
#       1 # reading the JSON data using json.load()
#       2 file = 'data.json'
# ----> 3 with open(file) as train_file:
#       4     dict_train = json.load(train_file)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.json'
