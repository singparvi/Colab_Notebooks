# %% [markdown]
# Objective 01 - concatenate data using the pandas concat method

# %%
# importing the library in python

import pandas as pd
import numpy as np

# %%
# Display the arguments for pd.concat()
# used for concatenation
pd.concat
# Out:
# <function pandas.core.reshape.concat.concat>

# %%
df1 = pd.DataFrame(np.random.rand(3,2), columns= ['cat' , 'dog'])
df2 = pd.DataFrame(np.random.rand(3,2), columns=['cat', 'dog'])

print (df1)
print (df2)
# Out:
#         cat       dog
# 0  0.015329  0.286834
# 1  0.392044  0.372526
# 2  0.689955  0.705993
#         cat       dog
# 0  0.548384  0.201216
# 1  0.973176  0.706411
# 2  0.725691  0.056737

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# using pd.concat to join rows
pd.concat([df1,df2])
# Out:
#         cat       dog
# 0  0.015329  0.286834
# 1  0.392044  0.372526
# 2  0.689955  0.705993
# 0  0.548384  0.201216
# 1  0.973176  0.706411
# 2  0.725691  0.056737

# %%
#output above has index as is using ignore=index
pd.concat([df1,df2], ignore_index= True)
# Out:
#         cat       dog
# 0  0.015329  0.286834
# 1  0.392044  0.372526
# 2  0.689955  0.705993
# 3  0.548384  0.201216
# 4  0.973176  0.706411
# 5  0.725691  0.056737

# %%
df1
# Out:
#         cat       dog
# 0  0.015329  0.286834
# 1  0.392044  0.372526
# 2  0.689955  0.705993

# %%
pd.concat([df1,df2], axis= 1)
# Out:
#         cat       dog       cat       dog
# 0  0.015329  0.286834  0.548384  0.201216
# 1  0.392044  0.372526  0.973176  0.706411
# 2  0.689955  0.705993  0.725691  0.056737

# %%
# sample taken from the module as is to keep pace
# Create the new DataFrame
df3 = pd.DataFrame(np.random.rand(3,2),
                  columns = ['bird', 'horse'])

# Concatenate it with one of the previous examples
pd.concat([df1, df3], axis=1)
# Out:
#         cat       dog      bird     horse
# 0  0.015329  0.286834  0.732048  0.112900
# 1  0.392044  0.372526  0.088179  0.077174
# 2  0.689955  0.705993  0.138199  0.907355

# %%
print (pd.concat([df1, df3]))
# Out:
#         cat       dog      bird     horse
# 0  0.015329  0.286834       NaN       NaN
# 1  0.392044  0.372526       NaN       NaN
# 2  0.689955  0.705993       NaN       NaN
# 0       NaN       NaN  0.732048  0.112900
# 1       NaN       NaN  0.088179  0.077174
# 2       NaN       NaN  0.138199  0.907355

# %%
# Create the DataFrames

data4 = {'Alpaca':['A1', 'A2', 'A3'], 'Bird':['B1', 'B2', 'B3'],
        'Camel':['C1', 'C2', 'C3']} 
df4 = pd.DataFrame(data4)
print(df4)

data5 = {'Bird':['B3', 'B4', 'B5'], 'Camel':['C3', 'C4', 'C5'],
        'Duck':['D3', 'D4', 'D5']} 
df5 = pd.DataFrame(data5, index=[3,4,5])
print(df5)

# Concatenate with default join='outer'
# (sort=False is used to suppress the warning that
# future pandas will no longer sort the rows) 
print(pd.concat([df4, df5], sort=False))
# Out:
#   Alpaca Bird Camel
# 0     A1   B1    C1
# 1     A2   B2    C2
# 2     A3   B3    C3
#   Bird Camel Duck
# 3   B3    C3   D3
# 4   B4    C4   D4
# 5   B5    C5   D5
#   Alpaca Bird Camel Duck
# 0     A1   B1    C1  NaN
# 1     A2   B2    C2  NaN
# 2     A3   B3    C3  NaN
# 3    NaN   B3    C3   D3
# 4    NaN   B4    C4   D4
# 5    NaN   B5    C5   D5

# %%
# the sample above has NaN in them for every missing cell where join was not possible 
# to only join columns that are common in two dataframe use join = inner

print(pd.concat([df4, df5], join='inner'))
# Out:
#   Bird Camel
# 0   B1    C1
# 1   B2    C2
# 2   B3    C3
# 3   B3    C3
# 4   B4    C4
# 5   B5    C5

# %% [markdown]
# Challenge
#
# Using the same process as above, practice concatenating some DataFrames that you create. You should follow these general steps:
#
# -Create DataFrames with either the np.array syntax or by creating a dictionary; create something that is ~10 rows
#
# -Concatenate along either the rows or columns, depending on the column names you created; experiment!
#
# -Use pd.concat with the join argument

# %%
df_A = pd.DataFrame(np.random.rand(10,2), columns= ['A', 'B'])
df_B = pd.DataFrame(np.random.rand(10,2), columns= ['C', 'D'])
print (df_A)
print (df_B)
# Out:
#           A         B
# 0  0.154849  0.763642
# 1  0.141669  0.999372
# 2  0.705439  0.332590
# 3  0.058946  0.509172
# 4  0.334375  0.865373
# 5  0.427002  0.563978
# 6  0.131100  0.883488
# 7  0.767042  0.104138
# 8  0.409210  0.716748
# 9  0.319084  0.626395
#           C         D
# 0  0.588244  0.718099
# 1  0.005374  0.789508
# 2  0.640791  0.495971
# 3  0.293038  0.433557
# 4  0.667790  0.681900
# 5  0.544747  0.468174
# 6  0.297050  0.962840
# 7  0.109614  0.299094
# 8  0.660044  0.838189
# 9  0.530340  0.532504

# %%
print (pd.concat([df_A, df_B]))
# Out:
#           A         B         C         D
# 0  0.154849  0.763642       NaN       NaN
# 1  0.141669  0.999372       NaN       NaN
# 2  0.705439  0.332590       NaN       NaN
# 3  0.058946  0.509172       NaN       NaN
# 4  0.334375  0.865373       NaN       NaN
# 5  0.427002  0.563978       NaN       NaN
# 6  0.131100  0.883488       NaN       NaN
# 7  0.767042  0.104138       NaN       NaN
# 8  0.409210  0.716748       NaN       NaN
# 9  0.319084  0.626395       NaN       NaN
# 0       NaN       NaN  0.588244  0.718099
# 1       NaN       NaN  0.005374  0.789508
# 2       NaN       NaN  0.640791  0.495971
# 3       NaN       NaN  0.293038  0.433557
# 4       NaN       NaN  0.667790  0.681900
# 5       NaN       NaN  0.544747  0.468174
# 6       NaN       NaN  0.297050  0.962840
# 7       NaN       NaN  0.109614  0.299094
# 8       NaN       NaN  0.660044  0.838189
# 9       NaN       NaN  0.530340  0.532504

# %%
df_A = pd.DataFrame(np.random.rand(10,2), columns= ['A', 'B'])
df_B = pd.DataFrame(np.random.rand(10,2), columns= ['B', 'C'])
print (df_A)
print (df_B)
# Out:
#           A         B
# 0  0.657182  0.490890
# 1  0.252982  0.997995
# 2  0.836115  0.040033
# 3  0.864116  0.762070
# 4  0.349615  0.486747
# 5  0.213694  0.881500
# 6  0.419656  0.125677
# 7  0.050871  0.490607
# 8  0.567373  0.982549
# 9  0.231121  0.862852
#           B         C
# 0  0.650813  0.969346
# 1  0.138804  0.545814
# 2  0.241562  0.364069
# 3  0.117133  0.830368
# 4  0.590580  0.576373
# 5  0.433067  0.507973
# 6  0.429961  0.716133
# 7  0.383995  0.589880
# 8  0.694340  0.086697
# 9  0.609456  0.989023

# %%
print (pd.concat([df_A, df_B], join = 'inner',ignore_index= True))
# Out:
#            B
# 0   0.490890
# 1   0.997995
# 2   0.040033
# 3   0.762070
# 4   0.486747
# 5   0.881500
# 6   0.125677
# 7   0.490607
# 8   0.982549
# 9   0.862852
# 10  0.650813
# 11  0.138804
# 12  0.241562
# 13  0.117133
# 14  0.590580
# 15  0.433067
# 16  0.429961
# 17  0.383995
# 18  0.694340
# 19  0.609456

# %% [markdown]
# Objective 02 - merge data using pandas merge

# %%
# Create DataFrames
df1 = pd.DataFrame({'day': ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri'],
                   'weather': ['sunny', 'windy', 'rainy', 'cloudy', 'cold']})
df2 = pd.DataFrame({'day': ['Wed', 'Fri', 'Mon', 'Thurs', 'Tues'],
                   'temp': [88, 75, 62, 65, 53]})
# Display the DataFrames
display(df1)
display(df2)

# Merge them with the default values
df3 = pd.merge(df1, df2)
display(df3)
# Out:
#      day weather
# 0    Mon   sunny
# 1   Tues   windy
# 2    Wed   rainy
# 3  Thurs  cloudy
# 4    Fri    cold
#      day  temp
# 0    Wed    88
# 1    Fri    75
# 2    Mon    62
# 3  Thurs    65
# 4   Tues    53
#      day weather  temp
# 0    Mon   sunny    62
# 1   Tues   windy    53
# 2    Wed   rainy    88
# 3  Thurs  cloudy    65
# 4    Fri    cold    75

# %%
# Change the column name day -> day_of_week
df2_new = pd.DataFrame({'day_of_week': ['Wed', 'Fri', 'Mon', 'Thurs', 'Tues'],
                   'temp': [88, 75, 62, 65, 53]})

# Merge with left and right columns
df4 = pd.merge(df1, df2_new, left_on='day', right_on='day_of_week')
display(df4)
# Out:
#      day weather day_of_week  temp
# 0    Mon   sunny         Mon    62
# 1   Tues   windy        Tues    53
# 2    Wed   rainy         Wed    88
# 3  Thurs  cloudy       Thurs    65
# 4    Fri    cold         Fri    75

# %%
# Drop the day_of_week column
df5 = pd.merge(df1, df2_new, left_on='day', right_on='day_of_week').drop('day_of_week', axis=1)
display(df5)
# Out:
#      day weather  temp
# 0    Mon   sunny    62
# 1   Tues   windy    53
# 2    Wed   rainy    88
# 3  Thurs  cloudy    65
# 4    Fri    cold    75

# %%
# Create the DataFrames
df6 = pd.DataFrame({'name': ['Snowball', 'Bob', 'Tweetie', 'Fluffy'],
                   'type': ['cat', 'rat', 'bird', 'dog']})

df7 = pd.DataFrame({'name': ['Snowball', 'Bob'],
                   'weight': [400, 749]})

# Display before merging
display(df6); display(df7)

# Merge in two different ways
df8_outer = pd.merge(df6, df7, how='outer')
df8_inner = pd.merge(df6, df7, how='inner',)

# Display after merging
display(df8_outer); display(df8_inner)
# Out:
#        name  type
# 0  Snowball   cat
# 1       Bob   rat
# 2   Tweetie  bird
# 3    Fluffy   dog
#        name  weight
# 0  Snowball     400
# 1       Bob     749
#        name  type  weight
# 0  Snowball   cat   400.0
# 1       Bob   rat   749.0
# 2   Tweetie  bird     NaN
# 3    Fluffy   dog     NaN
#        name type  weight
# 0  Snowball  cat     400
# 1       Bob  rat     749

# %%
# Reset indices 
df1a = df1.set_index('day')
df2a = df2.set_index('day')

display(df1a); display(df2a)

#??? there are some where we use pandas like pd.concat while others 
# we use df.join why and how do we distinuish?

df1a.join(df2a)
# Out:
#       weather
# day
# Mon     sunny
# Tues    windy
# Wed     rainy
# Thurs  cloudy
# Fri      cold
#        temp
# day
# Wed      88
# Fri      75
# Mon      62
# Thurs    65
# Tues     53
#       weather  temp
# day
# Mon     sunny    62
# Tues    windy    53
# Wed     rainy    88
# Thurs  cloudy    65
# Fri      cold    75

# %% [markdown]
# Challenge

# %%
df6 = pd.DataFrame({'name': ['Snowball', 'Bob', 'Tweetie', 'Fluffy'],
                   'type': ['cat', 'rat', 'bird', 'dog']})

df7 = pd.DataFrame({'name': ['Snowball', 'Bob'],
                   'weight': [400, 749]})

display(df6); display(df7)
# Out:
#        name  type
# 0  Snowball   cat
# 1       Bob   rat
# 2   Tweetie  bird
# 3    Fluffy   dog
#        name  weight
# 0  Snowball     400
# 1       Bob     749

# %%
#merge sample with inner
pd.merge(df6, df7, how = 'inner')
# Out:
#        name type  weight
# 0  Snowball  cat     400
# 1       Bob  rat     749

# %%
#merge sample with outer
pd.merge(df6, df7, how = 'outer')
# Out:
#        name  type  weight
# 0  Snowball   cat   400.0
# 1       Bob   rat   749.0
# 2   Tweetie  bird     NaN
# 3    Fluffy   dog     NaN

# %%
#concat sample with column concatenation
pd.concat([df6, df7], axis = 1)
# Out:
#        name  type      name  weight
# 0  Snowball   cat  Snowball   400.0
# 1       Bob   rat       Bob   749.0
# 2   Tweetie  bird       NaN     NaN
# 3    Fluffy   dog       NaN     NaN

# %%
#concat sample with rows concatenation
pd.concat([df6, df7], axis = 0, ignore_index= True)
# Out:
#        name  type  weight
# 0  Snowball   cat     NaN
# 1       Bob   rat     NaN
# 2   Tweetie  bird     NaN
# 3    Fluffy   dog     NaN
# 4  Snowball   NaN   400.0
# 5       Bob   NaN   749.0

# %%
df6.set_index('name', inplace= True)
df7.set_index('name', inplace= True)
df6.join(df7)
# Out:
#           type  weight
# name
# Snowball   cat   400.0
# Bob        rat   749.0
# Tweetie   bird     NaN
# Fluffy     dog     NaN

# %% [markdown]
# Objective 03 - define the concept of tidy data and describe the format

# %%
#Each variable is a column
# Each observation forms a row

# %% [markdown]
# Objective 04 - transition between tidy and wide data formats with the melt and pivot methods

# %%
# Create a DataFrame
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5}
                  })
display(df)

# Melt or unpivot the B column
pd.melt(df,id_vars= ['A'], value_vars= ['B'])
# Out:
#    A  B
# 0  a  1
# 1  b  3
# 2  c  5
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
# Create the DataFrame
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6]})

# Look at the DataFrame
display(df)

# Pivot with the given; again pivot is done on pd while melt on df
df.pivot(index = 'foo', columns = 'bar', values = 'baz')
# Out:
#    foo bar  baz
# 0  one   A    1
# 1  one   B    2
# 2  one   C    3
# 3  two   A    4
# 4  two   B    5
# 5  two   C    6
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
# Import seaborn
import seaborn as sns

# %%
#loading data
flights = sns.load_dataset('flights')
flights.head()
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_pivot = flights.pivot(index = 'year', columns= 'month', values = 'passengers')
display(flights_pivot)
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
ax = sns.heatmap(flights_pivot)

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_pivot = pd.pivot(diamonds,index = 'None', columns= 'cut', values= 'price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'None'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-9b36ac2d7282> in <module>()
# ...

# %%
diamonds.clarity[diamonds['clarity'].duplicated()].value_counts()
# Out:
# SI1     13064
# VS2     12257
# SI2      9193
# VS1      8170
# VVS2     5065
# VVS1     3654
# IF       1789
# I1        740
# Name: clarity, dtype: int64

# %%
diamonds['carat'].duplicated()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: carat, Length: 53940, dtype: bool

# %%
df.drop(), axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-fc4713e3acc1> in <module>()
# ----> 1 df.drop(diamonds[[diamonds.duplicated()]], axis = 0)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2938         elif len(key) != len(self.index):
#    2939             raise ValueError(
# -> 2940                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2941             )
#    2942
#
# ValueError: Item wrong length 1 instead of 53940.
